# %%
#Loading Data

import pandas as pd
ecommerce_df = pd.read_csv('global_ecommerce_sales.csv')
ecommerce_df.head()
# Out:
#     Order_ID  Order_Date   Customer_Name Customer_Segment        Country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11454  2023-01-05    Felix Thomas         Consumer          Italy
#
#           Region Product_Category                   Product_Name  Quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4         Europe        Furniture        Standing Desk Converter         4
#
#    Unit_Price  Discount_Percent  Total_Sales  Shipping_Cost  Profit  \
# 0       99.43                 0       298.29           9.31  124.92
# 1       97.93                20       313.38          14.31   83.62
# 2       10.74                 0        21.48           8.12    3.69
# 3       61.86                15       105.16          10.79   26.32
# 4      330.67                20      1058.14          11.09  253.44
#
#      Payment_Method
# 0  Cash on Delivery
# 1  Cash on Delivery
# 2       Credit Card
# 3            PayPal
# 4       Credit Card

# %%
#Dataset Structure

ecommerce_df.head()
ecommerce_df.info()
ecommerce_df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2000 non-null   str
#  1   Order_Date        2000 non-null   str
#  2   Customer_Name     2000 non-null   str
#  3   Customer_Segment  2000 non-null   str
#  4   Country           2000 non-null   str
#  5   Region            2000 non-null   str
#  6   Product_Category  2000 non-null   str
#  7   Product_Name      2000 non-null   str
#  8   Quantity          2000 non-null   int64
#  9   Unit_Price        2000 non-null   float64
#  10  Discount_Percent  2000 non-null   int64
#  11  Total_Sales       2000 non-null   float64
#  12  Shipping_Cost     2000 non-null   float64
#  13  Profit            2000 non-null   float64
#  14  Payment_Method    2000 non-null   str
# dtypes: float64(4), int64(2), str(9)
# memory usage: 234.5 KB
# (2000, 15)

# %%
# Explore Individual Columns

ecommerce_df['Product_Category'].value_counts()
ecommerce_df['Total_Sales'].describe()
# Out:
# count    2000.000000
# mean      242.279670
# std       382.583802
# min         2.420000
# 25%        41.227500
# 50%       113.125000
# 75%       266.552500
# max      3813.980000
# Name: Total_Sales, dtype: float64

# %%
#cleaning and wrangling

ecommerce_df.loc[
    ecommerce_df['Total_Sales'] > 500,
    ['Country', 'Total_Sales', 'Product_Category']
]
# Out:
#            Country  Total_Sales        Product_Category
# 4            Italy      1058.14               Furniture
# 8            China       634.81               Furniture
# 16         Nigeria       914.43               Furniture
# 17       Australia       848.92               Furniture
# 18          Mexico       579.48               Furniture
# ...            ...          ...                     ...
# 1966  South Africa       617.46               Furniture
# 1970   South Korea       827.42               Furniture
# 1992         Italy       969.81               Furniture
# 1995        France       523.65               Furniture
# 1996        France       619.37  Clothing & Accessories
#
# [257 rows x 3 columns]

# %%
df = (ecommerce_df['Total_Sales'] > 100) & (ecommerce_df["Country"] == "Italy")

ecommerce_df.sort_values(by='Customer_Name', ascending=True)
# Out:
#        Order_ID  Order_Date   Customer_Name Customer_Segment Country  \
# 1291  ORD-11384  2024-12-13       Ahmed Ali         Consumer  Mexico
# 1064  ORD-10629  2024-08-25  Ahmed Anderson      Home Office   China
# 47    ORD-10787  2023-02-01     Ahmed Clark         Consumer  Canada
# 806   ORD-10064  2024-04-05     Ahmed Clark        Corporate   Japan
# 1958  ORD-10888  2025-12-09    Ahmed Dubois         Consumer   Spain
# ...         ...         ...             ...              ...     ...
# 1298  ORD-11908  2024-12-15      Zara Weber         Consumer   Japan
# 886   ORD-11104  2024-05-14      Zara White         Consumer     UAE
# 91    ORD-11205  2023-02-24      Zara White         Consumer  France
# 1238  ORD-10150  2024-11-17   Zara Williams         Consumer   Japan
# 1800  ORD-10552  2025-09-26   Zara Williams         Consumer   Spain
#
#                     Region        Product_Category  \
# 1291         North America  Clothing & Accessories
# 1064          Asia Pacific              Technology
# 47           North America              Technology
# 806           Asia Pacific  Clothing & Accessories
# 1958                Europe              Technology
# ...                    ...                     ...
# 1298          Asia Pacific         Office Supplies
# 886   Middle East & Africa         Office Supplies
# 91                  Europe         Office Supplies
# 1238          Asia Pacific              Technology
# 1800                Europe              Technology
#
#                        Product_Name  Quantity  Unit_Price  Discount_Percent  \
# 1291            Cotton Formal Shirt        12       44.66                 5
# 1064            Smart LED Desk Lamp         4       33.42                 0
# 47              Tablet Stand Holder         3       19.94                 0
# 806             Cotton Formal Shirt         1       43.07                20
# 1958            Tablet Stand Holder         1       45.07                 5
# ...                             ...       ...         ...               ...
# 1298       Highlighters Neon Pack 6         4       12.49                 5
# 886           Ballpoint Pen Pack 12         5       10.88                 5
# 91       Binder Clips Assorted 48pc         6        7.14                 0
# 1238       Noise Cancelling Earbuds         7      123.89                 0
# 1800  Wireless Bluetooth Headphones         2      153.30                 5
#
#       Total_Sales  Shipping_Cost  Profit    Payment_Method
# 1291       509.12          14.12  227.04       Credit Card
# 1064       133.68          13.19   46.97            PayPal
# 47          59.82           8.61   18.31     Bank Transfer
# 806         34.46          10.50    2.43     Bank Transfer
# 1958        42.82           9.42    8.61  Cash on Delivery
# ...           ...            ...     ...               ...
# 1298        47.46          14.76   10.22     Bank Transfer
# 886         51.68          16.95   10.25       Credit Card
# 91          42.84          12.59   10.97            PayPal
# 1238       867.23          19.56  370.69       Credit Card
# 1800       291.27           8.25  114.39  Cash on Delivery
#
# [2000 rows x 15 columns]

# %%
ecommerce_df.rename(columns={
    "Total_Sales": "Sales"
}, inplace=True)
ecommerce_df.head()
# Out:
#     Order_ID  Order_Date   Customer_Name Customer_Segment        Country  \
# 0  ORD-11121  2023-01-02    Karen Suzuki        Corporate  United States
# 1  ORD-11244  2023-01-02  John Johansson        Corporate          Spain
# 2  ORD-10325  2023-01-03  Jessica Garcia         Consumer         Mexico
# 3  ORD-10467  2023-01-03    Clara Taylor        Corporate          Italy
# 4  ORD-11454  2023-01-05    Felix Thomas         Consumer          Italy
#
#           Region Product_Category                   Product_Name  Quantity  \
# 0  North America       Technology  Wireless Bluetooth Headphones         3
# 1         Europe       Technology     Mechanical Gaming Keyboard         4
# 2  North America  Office Supplies     Binder Clips Assorted 48pc         2
# 3         Europe       Technology                Webcam HD 1080p         2
# 4         Europe        Furniture        Standing Desk Converter         4
#
#    Unit_Price  Discount_Percent    Sales  Shipping_Cost  Profit  \
# 0       99.43                 0   298.29           9.31  124.92
# 1       97.93                20   313.38          14.31   83.62
# 2       10.74                 0    21.48           8.12    3.69
# 3       61.86                15   105.16          10.79   26.32
# 4      330.67                20  1058.14          11.09  253.44
#
#      Payment_Method
# 0  Cash on Delivery
# 1  Cash on Delivery
# 2       Credit Card
# 3            PayPal
# 4       Credit Card

# %%
ecommerce_df.drop(columns=['Region'], inplace=True)

# %%
ecommerce_df["Order_Date"] = pd.to_datetime(ecommerce_df["Order_Date"])
ecommerce_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2000 non-null   str
#  1   Order_Date        2000 non-null   datetime64[us]
#  2   Customer_Name     2000 non-null   str
#  3   Customer_Segment  2000 non-null   str
#  4   Country           2000 non-null   str
#  5   Product_Category  2000 non-null   str
#  6   Product_Name      2000 non-null   str
#  7   Quantity          2000 non-null   int64
#  8   Unit_Price        2000 non-null   float64
#  9   Discount_Percent  2000 non-null   int64
#  10  Sales             2000 non-null   float64
#  11  Shipping_Cost     2000 non-null   float64
#  12  Profit            2000 non-null   float64
#  13  Payment_Method    2000 non-null   str
# dtypes: datetime64[us](1), float64(4), int64(2), str(7)
# memory usage: 218.9 KB

# %%
ecommerce_df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_Name       0
# Customer_Segment    0
# Country             0
# Product_Category    0
# Product_Name        0
# Quantity            0
# Unit_Price          0
# Discount_Percent    0
# Sales               0
# Shipping_Cost       0
# Profit              0
# Payment_Method      0
# dtype: int64

# %%
ecommerce_df.duplicated()
ecommerce_df[ecommerce_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_Name, Customer_Segment, Country, Product_Category, Product_Name, Quantity, Unit_Price, Discount_Percent, Sales, Shipping_Cost, Profit, Payment_Method]
# Index: []

# %%
ecommerce_df.head()
ecommerce_df["Country"].unique()
ecommerce_df["Payment_Method"].unique()
ecommerce_df["Product_Category"].value_counts()
ecommerce_df["Customer_Segment"].unique()
ecommerce_df["Order_Date"].dtype
# Out:
# dtype('<M8[us]')

# %%
ecommerce_df[ecommerce_df["Sales"] < 0]
ecommerce_df[ecommerce_df["Profit"] < 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 7
#       2 ecommerce_df[ecommerce_df["Profit"] < 0]
#       4 ecommerce_df["Check_Profit"] = (
#       5     ecommerce_df["Sales"] - ecommerce_df["Shipping_Cost"]
#       6 )
# ----> 7 ecommerce_df[["Profit", 'check_Profit']]
#
# File c:\Users\sidha\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\sidha\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\sidha\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['check_Profit'] not in index"
